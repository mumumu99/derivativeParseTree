# %% [markdown]
# # Symdiff

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/22-1학기/수업/데이터구조/HW4/symbdiff'
# Out:
# /content/drive/MyDrive/22-1학기/수업/데이터구조/HW4/symbdiff

# %%
# !pip install pythonds
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pythonds
#   Downloading pythonds-1.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: pythonds
# Successfully installed pythonds-1.2.1

# %%
# %cd '/content/drive/MyDrive/22-1학기/수업/데이터구조/HW4/derivativeParseTree'
# Out:
# /content/drive/MyDrive/22-1학기/수업/데이터구조/HW4/derivativeParseTree

# %%
from tokenizer import tokenize
from postfix_SYA import postfix
from buildParseTree import buildParseTree
from diffTree import diffTree
from simplifyTree import simplifyTree
from infixTree import infixTree

def is_function(car):
    function_list = ["cos", "sin", "tan", "exp", "log"]
    if car in function_list:
        return 1
    else:
        return 0

# identical
def identicalTrees(a, b):
     
    # 1. Both empty
    if a is None and b is None:
        return True
 
    # 2. Both non-empty -> Compare them
    if a is not None and b is not None:
        return ((a.getRootVal() == b.getRootVal()) and
                identicalTrees(a.leftChild, b.leftChild)and
                identicalTrees(a.rightChild, b.rightChild))
     
    # 3. one empty, one not -- false
    return False

var = 'x'
#exp = "x^(-4)-x^3-x^2-x-1+sin(x)"
exp = "sin(x^2+x)+x"
#exp = 'sin(x)'
#exp = 'x*y*x*y*x'
#exp = '-12*(-a-cos(x)*3)-2'
print("Funcion: ", exp)

exp = tokenize(exp)
print("Tokenized: ", exp)

exp = postfix(exp)
print("postfix: ", exp)

pt = buildParseTree(exp)
print("buildParseTree: ", infixTree(pt))

diff_pt = diffTree(pt,var)
print("differativeTree: ", infixTree(diff_pt))
print('\n')

simp_diff_pt = simplifyTree(diff_pt)

print('Simplifying...')
counts = 0
while counts < 50 and not identicalTrees(simp_diff_pt, simplifyTree(simp_diff_pt)):
   simp_diff_pt = simplifyTree(simp_diff_pt)
   print(infixTree(simp_diff_pt))
   print('\n')
   counts = counts + 1

print("counts: ", counts)
# Out:
# Funcion:  sin(x^2+x)+x
# Tokenized:  ['sin', '(', 'x', '^', '2', '+', 'x', ')', '+', 'x']
# postfix:  ['x', '2', '^', 'x', '+', 'sin', 'x', '+']
# buildParseTree:  (sin(((x^2)+x))+x)
# differativeTree:  ((cos(((x^2)+x))*((((x^2)*(0*log(x)))+(2*(1*(x^(2-1)))))+1))+1)
#
#
# Simplifying...
# ((cos(((x^2)+x))*((0+(2*x))+1))+1)
#
#
# ((cos(((x^2)+x))*((2*x)+1))+1)
#
#
# counts:  2

# %% [markdown]
# ###Git
# Github commit

# %%
# !ls
# Out:
# buildParseTree.py  infix.py	 main.py	 __pycache__  simplifyTree.py
# diffTree.py	   infixTree.py  postfix_SYA.py  README.md    tokenizer.py

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/22-1학기/수업/데이터구조/HW4/derivativeParseTree/.git/

# %%
# !git config --global user.email "mumumu99@naver.com"
# !git config --global user.name "Muhyeon Kang"

# %%
# !git add .

# %%
# !git commit -m "First commit"
# Out:
# [main 998b46a] First commit
#  3 files changed, 49 insertions(+), 37 deletions(-)
#  rewrite infix.py (76%)
#  create mode 100644 infixTree.py
#  rename SYA.py => postfix_SYA.py (97%)

# %%
# !git remote add origin https://mumumu99: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@github.com/mumumu99/derivativeParseTree
# Out:
# fatal: remote origin already exists.

# %%
# !git remote rm origin

# %%
# !git branch -m master main

# %%
# !git push -u origin main
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.16 KiB | 296.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/mumumu99/derivativeParseTree
#    b81a365..998b46a  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !git checkout main
# Out:
# Already on 'main'
